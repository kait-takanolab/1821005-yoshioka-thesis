# %%
import numpy as np
a = np.array((1, 2, 3))
b = np.array((4, 5, 6))

# %% [markdown]
# このメソッドでは、要素の合計を返す numpy.sum() 関数を使用し、numpy.square() 関数は要素の 2 乗を返します。

# %%
dist = np.sqrt(np.sum(np.square(a-b)))
print(dist)
# Out:
# 5.196152422706632
